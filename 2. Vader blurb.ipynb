# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyser = SentimentIntensityAnalyzer()

# %%
df = pd.read_csv("KS_train_cleaned_1.0.csv")

# %%
df.head(5)
# Out:
#                                                blurb  staff_pick  funded  \
# 0  I will be an artist-in-residence at Elsewhere ...       False    True
# 1  1000 Artists is a public art-making installati...       False    True
# 2  The Sequel to ‘My Favorite Machine”, "MyPhoneH...       False    True
# 3  A film exploring the role and value of art edu...       False    True
# 4  We need to build a kitchen for Habitable Space...       False    True
#
#    days_to_launch  days_to_dealine  is_cat_art  is_cat_music  is_cat_film  \
# 0              81               22        True         False        False
# 1              24               40        True         False        False
# 2               7               60        True         False        False
# 3               8               21        True         False        False
# 4              52               30        True         False        False
#
#    is_cat_technology  is_cat_publishing  ...  is_2009  is_2010  is_2011  \
# 0              False              False  ...    False    False    False
# 1              False              False  ...    False    False    False
# 2              False              False  ...    False    False    False
# 3              False              False  ...    False    False    False
# 4              False              False  ...    False    False    False
#
#    is_2012  is_2013  is_2014  is_2015  is_2016  is_2017  is_2018
# 0     True    False    False    False    False    False    False
# 1     True    False    False    False    False    False    False
# 2     True    False    False    False    False    False    False
# 3     True    False    False    False    False    False    False
# 4     True    False    False    False    False    False    False
#
# [5 rows x 37 columns]

# %%
# df['sentiment'] = analyser.polarity_scores(df['blurb'].str)['compound']

df['blurb'].fillna(" ", inplace=True)

for index, value in df['blurb'].items():
    s = analyser.polarity_scores(value)
    df.at[index, 'sentiment_com'] = s['compound']
    
    df.at[index, 'sentiment_pos'] = (df.at[index, 'sentiment_com'] >= 0.05)
    df.at[index, 'sentiment_neu'] = (df.at[index, 'sentiment_com'] > -0.05 and df.at[index, 'sentiment_com'] < 0.05)
    df.at[index, 'sentiment_neg'] = (df.at[index, 'sentiment_com'] <= -0.05)
    
df['sentiment_pos'] = df['sentiment_pos'].astype('bool')
df['sentiment_neu'] = df['sentiment_neu'].astype('bool')
df['sentiment_neg'] = df['sentiment_neg'].astype('bool')
# Out:
#                                                    blurb  staff_pick  funded  \
# 0      I will be an artist-in-residence at Elsewhere ...       False    True
# 1      1000 Artists is a public art-making installati...       False    True
# 2      The Sequel to ‘My Favorite Machine”, "MyPhoneH...       False    True
# 3      A film exploring the role and value of art edu...       False    True
# 4      We need to build a kitchen for Habitable Space...       False    True
# 5      Source Material is 2 person exhibition of the ...       False    True
# 6      An anthropological field study of the Dwarven ...       False    True
# 7      Portrait artist seeks funds to kickstart an ex...        True    True
# 8      This is a month long Residency at the The Verm...        True    True
# 9      Art, Music, and Theater live on the Waterfront...       False    True
# 10     A mixed media thesis installation in which vis...       False    True
# 11     An artist book project bringing text and image...       False    True
# 12     Just Us Artists Initiative is pleased to prese...       False    True
# 13     An open-sourced "guerrilla wayfinding" project...        True    True
# 14     Assist Elysium Artwork in raising funds for ma...       False    True
# 15     The Boston Cod Piece is a giant Codfish on the...       False    True
# 16     Help us bring an urban oasis to Andersonville ...       False    True
# 17     This project is to make a t-shirt that simply ...        True    True
# 18     Bring 3 contemporary Iraqi female artists from...       False    True
# 19     The MPL-USA Art Tour is an interactive public ...       False    True
# 20     I'm in the last leg of getting work and prints...       False    True
# 21     April 5 I will open my studio to the public an...       False    True
# 22     I applied for an artist residency with Cercca/...       False    True
# 23     Help the beautification of Providence RI & New...       False    True
# 24     Cycling 15,000 miles across Europe+Asia to doc...        True    True
# 25     A collaborative ceramic art project joining we...       False    True
# 26     Creating large-scale wall collages for a solo ...       False    True
# 27     memory (loss) bank, a joint artistic endeavor ...       False    True
# 28     I have installed art onto the walls of cities ...       False    True
# 29     I am painting 26 large canvases, each with one...       False    True
# ...                                                  ...         ...     ...
# 95604  Support the circus arts and help our aerial st...       False    True
# 95605  Pickerington Community Theatre is seeking dona...       False    True
# 95606  Barebones Productions is developing a new thea...       False    True
# 95607  Le projet vise la création d’un lieu de réside...       False    True
# 95608  48 hours of deck screws, dry wall, hard hats a...       False    True
# 95609  Guilford Center Stage is a new project bringin...       False    True
# 95610  Hope Mill Theatre is a brand new Fringe Theatr...       False    True
# 95611  Love comedy? Get involved in creating a dedica...        True    True
# 95612  Help support the Acro-Cats kitten and cat resc...        True    True
# 95613  Help build an immersion experience for kids to...       False    True
# 95614  We're building a new theatre venue in Austin! ...       False    True
# 95615  The Montauk Surf Museum will present ocean sci...       False    True
# 95616  We're an affordable theatre and rental space t...       False    True
# 95617  By matching donations up to $5000, Jack Kesler...       False    True
# 95618  Wavy says let's LIGHT UP THE RAINBOW STAGE and...       False    True
# 95619  Introducing The Post at 750! Join us in the cr...       False    True
# 95620  A permanent home for comedy in Connecticut in ...       False    True
# 95621  Consuite for 2015 CoreCon.  An adventure into ...       False    True
# 95622  Let there be sound! Make our new theatre more ...       False    True
# 95623  Building Brooklyn's own creative venue for cir...        True    True
# 95624  Help us build a 200 seat theater and classroom...       False    True
# 95625  Help the hosts of the infamous St. Michael sus...       False    True
# 95626  Pangea House is a collectively run, all ages m...       False    True
# 95627  A place where innovation, food, creativity and...        True    True
# 95628  Steel City Improv Theater has found a new spac...       False    True
# 95629  Make the workshop/ small stage space at Jimmy'...       False    True
# 95630  Help create a permanent home for live comedy s...       False    True
# 95631  Voix de Ville is a pop-up imaginarium of neo-v...        True    True
# 95632  Help Synetic Theater create a new Studio to pr...       False    True
# 95633  Be part of building Cardiff's first pub theatr...       False    True
#
#        days_to_launch  days_to_dealine  is_cat_art  is_cat_music  is_cat_film  \
# 0                  81               22        True         False        False
# 1                  24               40        True         False        False
# 2                   7               60        True         False        False
# 3                   8               21        True         False        False
# 4                  52               30        True         False        False
# 5                  21               36        True         False        False
# 6                   3               12        True         False        False
# 7                  18               33        True         False        False
# 8                  11               45        True         False        False
# 9                  22               30        True         False        False
# 10                 13               20        True         False        False
# 11                 27               21        True         False        False
# 12                  4               25        True         False        False
# 13                 86               32        True         False        False
# 14                  5               30        True         False        False
# 15                  5               40        True         False        False
# 16                  8               30        True         False        False
# 17                 33                1        True         False        False
# 18                  3               15        True         False        False
# 19                  4               30        True         False        False
# 20                  2               30        True         False        False
# 21                  2               27        True         False        False
# 22                  9               41        True         False        False
# 23                  1               31        True         False        False
# 24                 60               42        True         False        False
# 25                  2               60        True         False        False
# 26                  9               29        True         False        False
# 27                113               20        True         False        False
# 28                  8               35        True         False        False
# 29                  8               30        True         False        False
# ...               ...              ...         ...           ...          ...
# 95604              32               60       False         False        False
# 95605              25               30       False         False        False
# 95606              16               30       False         False        False
# 95607              18               42       False         False        False
# 95608               0                4       False         False        False
# 95609               6               30       False         False        False
# 95610              48               30       False         False        False
# 95611              68               30       False         False        False
# 95612               6               40       False         False        False
# 95613               6               28       False         False        False
# 95614               3               29       False         False        False
# 95615              87               30       False         False        False
# 95616               2               30       False         False        False
# 95617               6               29       False         False        False
# 95618              27               30       False         False        False
# 95619               7               27       False         False        False
# 95620               5               60       False         False        False
# 95621               2               21       False         False        False
# 95622             249               60       False         False        False
# 95623              39               32       False         False        False
# 95624              65               30       False         False        False
# 95625               2               30       False         False        False
# 95626              17               30       False         False        False
# 95627               5               29       False         False        False
# 95628               3               30       False         False        False
# 95629              61               30       False         False        False
# 95630               2               30       False         False        False
# 95631              52               36       False         False        False
# 95632              16               36       False         False        False
# 95633               5               28       False         False        False
#
#        is_cat_technology  is_cat_publishing  ...  is_2012  is_2013  is_2014  \
# 0                  False              False  ...     True    False    False
# 1                  False              False  ...     True    False    False
# 2                  False              False  ...     True    False    False
# 3                  False              False  ...     True    False    False
# 4                  False              False  ...     True    False    False
# 5                  False              False  ...     True    False    False
# 6                  False              False  ...     True    False    False
# 7                  False              False  ...     True    False    False
# 8                  False              False  ...     True    False    False
# 9                  False              False  ...     True    False    False
# 10                 False              False  ...     True    False    False
# 11                 False              False  ...     True    False    False
# 12                 False              False  ...     True    False    False
# 13                 False              False  ...     True    False    False
# 14                 False              False  ...     True    False    False
# 15                 False              False  ...     True    False    False
# 16                 False              False  ...     True    False    False
# 17                 False              False  ...     True    False    False
# 18                 False              False  ...     True    False    False
# 19                 False              False  ...     True    False    False
# 20                 False              False  ...     True    False    False
# 21                 False              False  ...     True    False    False
# 22                 False              False  ...     True    False    False
# 23                 False              False  ...     True    False    False
# 24                 False              False  ...     True    False    False
# 25                 False              False  ...     True    False    False
# 26                 False              False  ...     True    False    False
# 27                 False              False  ...     True    False    False
# 28                 False              False  ...     True    False    False
# 29                 False              False  ...     True    False    False
# ...                  ...                ...  ...      ...      ...      ...
# 95604              False              False  ...    False    False    False
# 95605              False              False  ...    False    False    False
# 95606              False              False  ...    False    False    False
# 95607              False              False  ...    False    False    False
# 95608              False              False  ...    False    False    False
# 95609              False              False  ...    False    False    False
# 95610              False              False  ...    False    False    False
# 95611              False              False  ...    False    False    False
# 95612              False              False  ...    False    False    False
# 95613              False              False  ...    False    False     True
# 95614              False              False  ...    False    False     True
# 95615              False              False  ...    False    False     True
# 95616              False              False  ...    False    False     True
# 95617              False              False  ...    False    False     True
# 95618              False              False  ...    False    False    False
# 95619              False              False  ...    False    False    False
# 95620              False              False  ...    False    False    False
# 95621              False              False  ...    False    False    False
# 95622              False              False  ...    False    False     True
# 95623              False              False  ...    False    False     True
# 95624              False              False  ...    False    False     True
# 95625              False              False  ...    False    False     True
# 95626              False              False  ...    False    False     True
# 95627              False              False  ...    False    False     True
# 95628              False              False  ...     True    False    False
# 95629              False              False  ...     True    False    False
# 95630              False              False  ...    False     True    False
# 95631              False              False  ...    False     True    False
# 95632              False              False  ...    False     True    False
# 95633              False              False  ...    False    False     True
#
#        is_2015  is_2016  is_2017  is_2018  sentiment_pos  sentiment_neu  \
# 0        False    False    False    False          False           True
# 1        False    False    False    False          False           True
# 2        False    False    False    False           True          False
# 3        False    False    False    False           True          False
# 4        False    False    False    False          False           True
# 5        False    False    False    False          False           True
# 6        False    False    False    False          False           True
# 7        False    False    False    False           True          False
# 8        False    False    False    False           True          False
# 9        False    False    False    False           True          False
# 10       False    False    False    False           True          False
# 11       False    False    False    False           True          False
# 12       False    False    False    False           True          False
# 13       False    False    False    False           True          False
# 14       False    False    False    False           True          False
# 15       False    False    False    False          False           True
# 16       False    False    False    False           True          False
# 17       False    False    False    False          False           True
# 18       False    False    False    False          False           True
# 19       False    False    False    False           True          False
# 20       False    False    False    False           True          False
# 21       False    False    False    False          False           True
# 22       False    False    False    False           True          False
# 23       False    False    False    False           True          False
# 24       False    False    False    False          False           True
# 25       False    False    False    False          False           True
# 26       False    False    False    False           True          False
# 27       False    False    False    False          False           True
# 28       False    False    False    False           True          False
# 29       False    False    False    False           True          False
# ...        ...      ...      ...      ...            ...            ...
# 95604    False     True    False    False           True          False
# 95605     True    False    False    False           True          False
# 95606     True    False    False    False          False           True
# 95607     True    False    False    False          False           True
# 95608     True    False    False    False           True          False
# 95609     True    False    False    False          False           True
# 95610     True    False    False    False           True          False
# 95611     True    False    False    False           True          False
# 95612     True    False    False    False           True          False
# 95613    False    False    False    False           True          False
# 95614    False    False    False    False           True          False
# 95615    False    False    False    False           True          False
# 95616    False    False    False    False          False           True
# 95617    False    False    False    False           True          False
# 95618     True    False    False    False           True          False
# 95619     True    False    False    False           True          False
# 95620     True    False    False    False           True          False
# 95621     True    False    False    False          False          False
# 95622    False    False    False    False          False           True
# 95623    False    False    False    False           True          False
# 95624    False    False    False    False           True          False
# 95625    False    False    False    False           True          False
# 95626    False    False    False    False          False          False
# 95627    False    False    False    False           True          False
# 95628    False    False    False    False          False           True
# 95629    False    False    False    False           True          False
# 95630    False    False    False    False           True          False
# 95631    False    False    False    False           True          False
# 95632    False    False    False    False           True          False
# 95633    False    False    False    False          False           True
#
#        sentiment_neg
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# 6              False
# 7              False
# 8              False
# 9              False
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False
# 19             False
# 20             False
# 21             False
# 22             False
# 23             False
# 24             False
# 25             False
# 26             False
# 27             False
# 28             False
# 29             False
# ...              ...
# 95604          False
# 95605          False
# 95606          False
# 95607          False
# 95608          False
# 95609          False
# 95610          False
# 95611          False
# 95612          False
# 95613          False
# 95614          False
# 95615          False
# 95616          False
# 95617          False
# 95618          False
# 95619          False
# 95620          False
# 95621           True
# 95622          False
# 95623          False
# 95624          False
# 95625          False
# 95626           True
# 95627          False
# 95628          False
# 95629          False
# 95630          False
# 95631          False
# 95632          False
# 95633          False
#
# [95634 rows x 40 columns]

# %%
df = df.drop(['sentiment_com'], axis=1)

# %%
df.head(10)
# Out:
#                                                blurb  staff_pick  funded  \
# 0  I will be an artist-in-residence at Elsewhere ...       False    True
# 1  1000 Artists is a public art-making installati...       False    True
# 2  The Sequel to ‘My Favorite Machine”, "MyPhoneH...       False    True
# 3  A film exploring the role and value of art edu...       False    True
# 4  We need to build a kitchen for Habitable Space...       False    True
# 5  Source Material is 2 person exhibition of the ...       False    True
# 6  An anthropological field study of the Dwarven ...       False    True
# 7  Portrait artist seeks funds to kickstart an ex...        True    True
# 8  This is a month long Residency at the The Verm...        True    True
# 9  Art, Music, and Theater live on the Waterfront...       False    True
#
#    days_to_launch  days_to_dealine  is_cat_art  is_cat_music  is_cat_film  \
# 0              81               22        True         False        False
# 1              24               40        True         False        False
# 2               7               60        True         False        False
# 3               8               21        True         False        False
# 4              52               30        True         False        False
# 5              21               36        True         False        False
# 6               3               12        True         False        False
# 7              18               33        True         False        False
# 8              11               45        True         False        False
# 9              22               30        True         False        False
#
#    is_cat_technology  is_cat_publishing  ...  is_2012  is_2013  is_2014  \
# 0              False              False  ...     True    False    False
# 1              False              False  ...     True    False    False
# 2              False              False  ...     True    False    False
# 3              False              False  ...     True    False    False
# 4              False              False  ...     True    False    False
# 5              False              False  ...     True    False    False
# 6              False              False  ...     True    False    False
# 7              False              False  ...     True    False    False
# 8              False              False  ...     True    False    False
# 9              False              False  ...     True    False    False
#
#    is_2015  is_2016  is_2017  is_2018  sentiment_pos  sentiment_neu  \
# 0    False    False    False    False          False           True
# 1    False    False    False    False          False           True
# 2    False    False    False    False           True          False
# 3    False    False    False    False           True          False
# 4    False    False    False    False          False           True
# 5    False    False    False    False          False           True
# 6    False    False    False    False          False           True
# 7    False    False    False    False           True          False
# 8    False    False    False    False           True          False
# 9    False    False    False    False           True          False
#
#    sentiment_neg
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
#
# [10 rows x 40 columns]

# %%
df.to_csv("KS_train_w_vader.csv", index=False)
